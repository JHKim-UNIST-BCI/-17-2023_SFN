# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import time
import matplotlib.pyplot as plt
from SNN_JHK_v1_230308 import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# receptiveField = [np.array([[10]]),np.array([[2,2],[2,2]]),np.array([[3,3,3],[3,3,3],[3,3,3]])]
receptiveField = [np.array([[10]])]
# print(len(receptiveField))
# [print(row) for row in receptiveField]

rf = createReceptiveField(receptiveField,1,7,3)

print(len(rf[0]))
# Out:
# Complete! Create 1x1 kernel! with 21 times.
# 42

# %%
import scipy.io

mat = scipy.io.loadmat('DATA/InputSpike_4class.mat')

input = mat['input']
inputTime = mat['inputTime']

print(type(mat))
for i in mat:
    print(i)


print(input.shape)
print(input[0][2].shape)

plt.plot(inputTime, input[0][42])
# Out:
# <class 'dict'>
# __header__
# __version__
# __globals__
# input
# inputTime
# (1, 52)
# (3620, 42)
# ...
